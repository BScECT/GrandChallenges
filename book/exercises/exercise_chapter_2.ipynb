# %% [markdown]
# # Exercise Chapter 2 - Operators and variables

# %% [markdown]
# ## 2.1 Python Variables

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Exercise 2.1.1<br><br></b><div style="text-align: justify">You just landed your first paying gig: tutoring high-schoolers in math. Naturally, the tax office wants their share too, and the taxes you need to pay is the product of your income and the tax rate. Complete the line below to assign the correct calculation for the <code>my_taxes</code> variable. Use the <code>my_income</code> and <code>tax_rate</code> variables for that.<br>
# </div></div>
#
# <div class="alert alert-block alert-warning"><b></b> The dotted lines (...) below mark the location where you should change the code yourself! </div> To run the code, press control + enter (for windows) or cmd + enter (for mac).

# %%
my_income = 100
tax_rate = 0.1
my_taxes = ...
print(my_taxes)
# Out:
# Ellipsis

# %% [markdown]
# Use the cell block below to find out what is the **`type`** of the variable **`my_taxes`**

# %%
# use this line to check the type of the variable my_taxes
...
# Out:
# Ellipsis

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Exercise 2.1.2<br><br></b>
# <div style="text-align: justify">
#
# What is the type of the result of the expression $3 + 1.5 + 4?$
#
# <br>Assign the type to the variable beneath (e.g. if you think it is an integer then <code>expression_type = int</code>)
# </div></div>

# %%
expression_type = ...
# Out:
# Ellipsis

# %% [markdown]
# ## 2.2 Python Operators

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Exercise 2.2.1</b><br><br>
#
# Given that we have a rectangle with a height of $3$ cm, width of $5$ cm and a cutout circle of radius $0.6$ cm, as shown below.
#
# ![Figure 1](../figures/Week2/rectangle.png)
#
# <br>What will the remainder area of the rectangle be? Hint: $A_{circle} = \pi r^2$
#
# </div>

# %%
# variables for the rectangle
rect_h = ...
rect_w = ...

# variables for the circle
pi = 3.14159265359
r = ...

# calculating area
circle_area = ...
rect_area = ...
remaining_area = ...

print('The remaining area is', remaining_area, 'cm^2')
# Out:
# The remaining area is Ellipsis cm^2

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercise 2.2.2</b>
#
# Suppose a group of $5$ engineers ordered $3$ pizzas with $8$ slices each and  want to share their meal equally. Your task is to calculate the amount of pizza slices each engineer will get and the amount of slices which will be left untouched.
# </div>

# %%
pizza_slices = ...
grp_members = ...

slices_per_person = ...
left_over_slices = ...

print('Number of slices per person:', slices_per_person)
print('Number of slices left over:', left_over_slices)
# Out:
# Number of slices per person: Ellipsis
# Number of slices left over: Ellipsis

# %% [markdown]
# ## 2.3 Large equations

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Exercise 2.3.1</b><br><br>
#
# You're modeling a roller coaster cart for a physics project. At any point on the track, its total mechanical energy is the sum of its kinetic energy and potential energy:
#
# $$E = \frac{1}{2}mv^2 + mgh$$
#
# where $m$ is the mass in kg, $v$ is the velocity in m/s, $g$ is the gravitational acceleration ($9.81 \ m/s^2$), and $h$ is the height in meters.
#
# The cart has a mass of $250$ kg, is moving at $12$ m/s, and is currently $8$ m above the ground. Complete the line below to calculate <code>total_energy</code> in a **single expression**. No separate variables for kinetic and potential energy is allowed. Use parentheses to make sure to get the order of operations right.
#
# </div></div>

# %%
# variables
m = 250
v = 12
h = 8
g = 9.81

# calculate total mechanical energy in one line
total_energy = ...

print('The total mechanical energy is', total_energy, 'Joules')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Exercise 2.3.2</b><br><br>
#
# A classmate wrote the same calculation slightly differently:
#
# <code>total_energy_v2 = 1/2*m*v**2+m*g*h</code>
#
# Does this give the same result as your answer above? Run it and check. Then, in the cell below, explain in your own words (as a comment) why the two either do or don't match, and which operator precedence rules are responsible.
#
# </div>

# %%
total_energy_v2 = ...
print(...)
# your explanation here:
...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Exercise 2.3.3</b><br><br>
#
# One-liners are neat, but they're not always the most readable choice, especially for a longer physics report where someone else (or future you) needs to follow your steps. Rewrite the energy calculation from Exercise 2.3.1, but this time split it into clear, separate parts: one variable for the kinetic energy, one for the potential energy, and a final one that adds them together.
#
# </div></div>

# %%
# variables (same as before)
m = 250
v = 12
h = 8
g = 9.81

# step 1: calculate the kinetic energy
kinetic_energy = ...

# step 2: calculate the potential energy
potential_energy = ...

# step 3: add them together
total_energy_split = ...

print('Kinetic energy:', kinetic_energy, 'Joules')
print('Potential energy:', potential_energy, 'Joules')
print('Total mechanical energy:', total_energy_split, 'Joules')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Check that <code>total_energy_split</code> matches the <code>total_energy</code> you calculated in Exercise 2.3.1. If it doesn't, you've likely made a small error along the way. This is exactly why breaking equations into parts is useful: it's much easier to spot where a mistake happened when each step has its own variable.
#
# </div>
